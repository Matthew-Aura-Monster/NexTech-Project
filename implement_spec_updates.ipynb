# %%
# Implement Specification and Style Guide Updates

This notebook reviews the specification and style guide, then updates the web app prototype to match the new Stellar Planets concept.

## Outline
1. Review Specification and Style Guide
2. Update App Description
3. Apply Style and Theme Changes
4. Define User Scenarios
5. Generate Simulated Data for `items-template.csv`
6. Explain Implementation Changes
</VSCode.Cell>
<VSCode.Cell language="python">
from pathlib import Path

spec = Path('specification.md').read_text(encoding='utf-8')
style = Path('style-guide.html').read_text(encoding='utf-8')
print('--- specification.md ---')
print(spec[:1500])
print('\n--- style-guide.html ---')
print(style[:1500])
</VSCode.Cell>
